# %%
import os 
import pandas as pd
import numpy as np
import shutil
import random

db_original_path = "/local/scratch/Figaro/data/retailer"
db_pk_path = "/local/scratch/Figaro/data/retailer_pk"

shutil.copytree(db_original_path, db_pk_path)

percents = np.linspace(0.01, 0.01, num=1)

db_paths = [ os.path.join(db_pk_path, str(round(per, 2))) for per in percents]
print(db_paths)

def reduce_column_size(t: pd.DataFrame, percent: float, column: str):
    unique_vals_s = set(t[column].unique().tolist())
    reduced_num_cols =  int(len(unique_vals_s) * percent)
    map_vals_to = random.sample(unique_vals_s, reduced_num_cols)
    
    dic_mappings = {}
    
    for idx, unique_value in enumerate(unique_vals_s):
        dic_mappings [unique_value] = map_vals_to[idx % reduced_num_cols]

    t[column].replace(to_replace=dic_mappings, inplace=True)
    print("Before:", len(unique_vals_s))
    print("Reduced number:", len(set(t[column].unique().tolist())))





for db_path in db_paths:
    for file_name in os.listdir(db_path):
        if file_name.startswith("Inventory"):
            full_path = os.path.join(db_path, file_name)
            print(file_name)
            print(full_path)
            t_original = pd.read_csv(full_path, header=None)
            percents_column = np.linspace(0.1, 1, num=10)
            for percent_column in percents_column:
                t = t_original.copy()
                full_path_column = os.path.join(db_path, str(round(percent_column, 2)) + file_name)
                print(full_path_column)
                t.columns = ["Locn", "DateId", "Ksn", "InventoryUnits"]
                t["LocnC"] = t["Locn"]
                t["DateIdC"] = t["DateId"]
                t["KsnC"] = t["Ksn"]
                
                reduce_column_size(t, percent_column, "KsnC")
                t.to_csv(full_path_column, index=False, header=None)
        
        if file_name.startswith("Census"):
            full_path = os.path.join(db_path, file_name)
            print(file_name)
            print(full_path)
            t = pd.read_csv(full_path, header=None)
            t.columns = ["Zip", "Population", "White", "Asian", "Pacific", "Black", "MedianAge", "OccupiedHouseUnits", "HouseUnits", "Families", "Households", "HusbWife", "Males", "Females", "HouseholdChildren", "Hispanic"]
            t["ZipC"] = t["Zip"]
            t.to_csv(full_path, index=False, header=None)
# Out:
# ['/local/scratch/Figaro/data/retailer_pk/0.01', '/local/scratch/Figaro/data/retailer_pk']
# Census.csv
# /local/scratch/Figaro/data/retailer_pk/0.01/Census.csv
# Inventory.csv
# /local/scratch/Figaro/data/retailer_pk/0.01/Inventory.csv
# /local/scratch/Figaro/data/retailer_pk/0.01/0.1Inventory.csv
# Before: 1987
# Reduced number: 198
# /local/scratch/Figaro/data/retailer_pk/0.01/0.2Inventory.csv
# Before: 1987
# Reduced number: 397
# /local/scratch/Figaro/data/retailer_pk/0.01/0.3Inventory.csv
# Before: 1987
# Reduced number: 596
# /local/scratch/Figaro/data/retailer_pk/0.01/0.4Inventory.csv
# Before: 1987
# Reduced number: 794
# /local/scratch/Figaro/data/retailer_pk/0.01/0.5Inventory.csv
# Before: 1987
# Reduced number: 993
# /local/scratch/Figaro/data/retailer_pk/0.01/0.6Inventory.csv
# Before: 1987
# Reduced number: 1192
# /local/scratch/Figaro/data/retailer_pk/0.01/0.7Inventory.csv
# Before: 1987
# Reduced number: 1390
# /local/scratch/Figaro/data/retailer_pk/0.01/0.8Inventory.csv
# Before: 1987
# Reduced number: 1589
# /local/scratch/Figaro/data/retailer_pk/0.01/0.9Inventory.csv
# Before: 1987
# Reduced number: 1788
# /local/scratch/Figaro/data/retailer_pk/0.01/1.0Inventory.csv
# Before: 1987
# Reduced number: 1987
# Census.csv
# /local/scratch/Figaro/data/retailer_pk/Census.csv
# Inventory.csv
# /local/scratch/Figaro/data/retailer_pk/Inventory.csv
# /local/scratch/Figaro/data/retailer_pk/0.1Inventory.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32519/3567307538.py in <module>
#      50                 t["KsnC"] = t["Ksn"]
#      51
# ---> 52                 reduce_column_size(t, percent_column, "KsnC")
#      53                 t.to_csv(full_path_column, index=False, header=None)
#      54
#
# /tmp/ipykernel_32519/3567307538.py in reduce_column_size(t, percent, column)
#      25         dic_mappings [unique_value] = map_vals_to[idx % reduced_num_cols]
#      26
# ---> 27     t[column].replace(to_replace=dic_mappings, inplace=True)
#      28     print("Before:", len(unique_vals_s))
#      29     print("Reduced number:", len(set(t[column].unique().tolist())))
#
# /local/scratch/Figaro/figaro-code/scripts/run-env-mkl/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4579             limit=limit,
#    4580             regex=regex,
# -> 4581             method=method,
#    4582         )
#    4583
#
# /local/scratch/Figaro/figaro-code/scripts/run-env-mkl/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6499
#    6500             return self.replace(
# -> 6501                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6502             )
#    6503         else:
#
# /local/scratch/Figaro/figaro-code/scripts/run-env-mkl/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4579             limit=limit,
#    4580             regex=regex,
# -> 4581             method=method,
#    4582         )
#    4583
#
# /local/scratch/Figaro/figaro-code/scripts/run-env-mkl/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6545                         dest_list=value,
#    6546                         inplace=inplace,
# -> 6547                         regex=regex,
#    6548                     )
#    6549
#
# /local/scratch/Figaro/figaro-code/scripts/run-env-mkl/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# /local/scratch/Figaro/figaro-code/scripts/run-env-mkl/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# /local/scratch/Figaro/figaro-code/scripts/run-env-mkl/lib/python3.7/site-packages/pandas/core/internals/managers.py in comp(s, mask, regex)
#     634
#     635             s = com.maybe_box_datetimelike(s)
# --> 636             return _compare_or_regex_search(values, s, regex, mask)
#     637
#     638         # Calculate the mask once, prior to the call of comp
#
# /local/scratch/Figaro/figaro-code/scripts/run-env-mkl/lib/python3.7/site-packages/pandas/core/internals/managers.py in _compare_or_regex_search(a, b, regex, mask)
#    1986         mask = np.reshape(~(isna(a)), a.shape)
#    1987     if isinstance(a, np.ndarray):
# -> 1988         a = a[mask]
#    1989
#    1990     if is_datetimelike_v_numeric(a, b) or is_numeric_v_string_like(a, b):
#
# KeyboardInterrupt:

# %%
import os 
import pandas as pd
import numpy as np
import shutil

figaro_data_path = "/local/scratch/Figaro/data"
db_original_path = os.path.join(figaro_data_path, "favorita")
db_pk_path = db_original_path + "_pk"

shutil.copytree(db_original_path, db_pk_path)
percents = np.linspace(0.01, 0.1, num=10)

db_paths = [ os.path.join(db_pk_path, str(round(per, 2))) for per in percents] + [db_pk_path]

for db_path in db_paths:
    for file_name in os.listdir(db_path):
        if file_name.startswith("Sales"):
            full_path = os.path.join(db_path, file_name)
            print(file_name)
            print(full_path)
            t = pd.read_csv(full_path, header=None)
            t.columns = ["Date","Store","Item","UnitSales","OnPromotion"]
            t["DateC"] = t["Date"]
            t["StoreC"] = t["Store"]
            t["ItemC"] = t["Item"]
            t.to_csv(full_path, index=False, header=None)

# %%
import os 
import pandas as pd
import numpy as np
import shutil

db_original_path = "/local/scratch/Figaro/data/yelp"
db_pk_path = "/local/scratch/Figaro/data/yelp_pk"

shutil.copytree(db_original_path, db_pk_path)
percents = np.linspace(0.01, 0.1, num=10)

db_paths = [ os.path.join(db_pk_path, str(round(per, 2))) for per in percents] + [db_pk_path]


for db_path in db_paths:
    for file_name in os.listdir(db_path):
        if file_name.startswith("review"):
            full_path = os.path.join(db_path, file_name)
            print(file_name)
            print(full_path)
            t = pd.read_csv(full_path, header=None)
            t.columns = ["BusinessId","UserId","ReviewId","StarsR","ReviewYear","ReviewMonth","ReviewDay","Useful","Funny","Cool"]
            t["BusinessIdC"] = t["BusinessId"]
            t["UserIdC"] = t["UserId"]
            t["ReviewIdC"] = t["ReviewId"]
            t.to_csv(full_path, index=False, header=None)
